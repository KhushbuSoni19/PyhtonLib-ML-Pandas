# %% [markdown]
# # how to Write CSV file With Pandas

# %%
import pandas as pd

# %%
#  read csv /text file
# pd.read_csv(_path_)
df = pd.read_csv('E:\ML\Statewise.csv', nrows = 10)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# columns 
df.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
df
# Out:
#          Date                        State   TotalSamples       Negative  \
# 0  2020-04-27  Andaman and Nicobar Islands           2848       no value
# 1  2020-04-27               Andhra Pradesh          74551          73374
# 2  2020-04-28            Arunachal Pradesh  not availbale  not availbale
# 3  2020-04-27                        Assam           8117           7985
# 4  2020-04-27                   Chandigarh            843            777
# 5  2020-04-27                        Delhi          39911          34145
# 6  2020-04-27                          Goa           1541  not availbale
# 7  2020-04-27                      Gujarat          53575          50028
# 8  2020-04-27                      Haryana          22993          20702
# 9  2020-04-27             Himachal Pradesh           5106           5022
#
#    Positive
# 0      33.0
# 1    1177.0
# 2       NaN
# 3      35.0
# 4      40.0
# 5    3108.0
# 6       7.0
# 7    3547.0
# 8     301.0
# 9      40.0

# %%
df = pd.read_csv('E:\ML\Statewise.csv', usecols = [1])
print(df)
# Out:
#                           State
# 0   Andaman and Nicobar Islands
# 1                Andhra Pradesh
# 2             Arunachal Pradesh
# 3                         Assam
# 4                    Chandigarh
# 5                         Delhi
# 6                           Goa
# 7                       Gujarat
# 8                       Haryana
# 9              Himachal Pradesh
# 10            Jammu and Kashmir
# 11                    Jharkhand
# 12                    Karnataka
# 13                       Kerala
# 14               Madhya Pradesh
# 15                  Maharashtra
# 16                    Meghalaya
# 17                      Mizoram
# 18                     Nagaland
# 19                       Odisha
# 20                   Puducherry
# 21                       Punjab
# 22                    Rajasthan
# 23                   Tamil Nadu
# 24                      Tripura
# 25                Uttar Pradesh
# 26                  Uttarakhand
# 27                  West Bengal

# %%
# nrows for, how many rows we have to print
df = pd.read_csv('E:\ML\hospitalData.csv',nrows =10)
df
# Out:
#    age     sex           Province                cp  trestbps  chol    fbs  \
# 0   63    Male     Andhra Pradesh      asymptomatic       145   233   True
# 1   37    Male  Arunachal Pradesh  non-anginal pain       130   250  False
# 2   41  Female              Assam   atypical angina       130   204  False
# 3   56    Male              Bihar   atypical angina       120   236  False
# 4   57  Female       Chhattisgarh    typical angina       120   354  False
# 5   57    Male          Karnataka    typical angina       140   192  False
# 6   56  Female             Punjab   atypical angina       140   294  False
# 7   44    Male            Haryana   atypical angina       120   263  False
# 8   52    Male   Himachal Pradesh  non-anginal pain       172   199   True
# 9   57    Male          Jharkhand  non-anginal pain       150   168  False
#
#    restecg  thalach  exang  oldpeak  slope  ca  thal    target
# 0    False      150      0      2.3      0   0     1  Effected
# ...

# %%
# usecols = column index as list
df = pd.read_csv('E:\ML\hospitalData.csv',usecols=[2,14],nrows=11)
df
# Out:
#              Province    target
# 0      Andhra Pradesh  Effected
# 1   Arunachal Pradesh  Effected
# 2               Assam  Effected
# 3               Bihar  Effected
# 4        Chhattisgarh  Effected
# 5           Karnataka  Effected
# 6              Punjab  Effected
# 7             Haryana  Effected
# 8    Himachal Pradesh  Effected
# 9           Jharkhand  Effected
# 10                Goa  Effected

# %%
df = pd.read_csv('E:\ML\hospitalData.csv')
df
# Out:
#      age     sex           Province                cp  trestbps  chol    fbs  \
# 0     63    Male     Andhra Pradesh      asymptomatic       145   233   True
# 1     37    Male  Arunachal Pradesh  non-anginal pain       130   250  False
# 2     41  Female              Assam   atypical angina       130   204  False
# 3     56    Male              Bihar   atypical angina       120   236  False
# 4     57  Female       Chhattisgarh    typical angina       120   354  False
# ..   ...     ...                ...               ...       ...   ...    ...
# 298   57  Female   Himachal Pradesh    typical angina       140   241  False
# 299   45    Male                Goa      asymptomatic       110   264  False
# 300   68    Male             Sikkim    typical angina       144   193   True
# 301   57    Male            Gujarat    typical angina       130   131  False
# 302   57  Female          Telangana   atypical angina       130   236  False
#
# ...

# %%
# skiprows =  rows skip from up
df = pd.read_csv('E:\ML\hospitalData.csv',nrows =10,skiprows =3)
df
# Out:
#    41  Female             Assam   atypical angina  130  204  FALSE  FALSE.1  \
# 0  56    Male             Bihar   atypical angina  120  236  False     True
# 1  57  Female      Chhattisgarh    typical angina  120  354  False     True
# 2  57    Male         Karnataka    typical angina  140  192  False     True
# 3  56  Female            Punjab   atypical angina  140  294  False    False
# 4  44    Male           Haryana   atypical angina  120  263  False     True
# 5  52    Male  Himachal Pradesh  non-anginal pain  172  199   True     True
# 6  57    Male         Jharkhand  non-anginal pain  150  168  False     True
# 7  54    Male               Goa    typical angina  140  239  False     True
# 8  48  Female            Kerala  non-anginal pain  130  275  False     True
# 9  49    Male    Madhya Pradesh   atypical angina  130  266  False     True
#
#    172  0  1.4  2  0.1  2.1  Effected
# 0  178  0  0.8  2    0    2  Effected
# 1  163  1  0.6  2    0    2  Effected
# ...

# %%
# skiprows =  skip particular row which we have to skip
df = pd.read_csv('E:\ML\hospitalData.csv',nrows =10,skiprows = [1])
df
# Out:
#    age     sex           Province                cp  trestbps  chol    fbs  \
# 0   37    Male  Arunachal Pradesh  non-anginal pain       130   250  False
# 1   41  Female              Assam   atypical angina       130   204  False
# 2   56    Male              Bihar   atypical angina       120   236  False
# 3   57  Female       Chhattisgarh    typical angina       120   354  False
# 4   57    Male          Karnataka    typical angina       140   192  False
# 5   56  Female             Punjab   atypical angina       140   294  False
# 6   44    Male            Haryana   atypical angina       120   263  False
# 7   52    Male   Himachal Pradesh  non-anginal pain       172   199   True
# 8   57    Male          Jharkhand  non-anginal pain       150   168  False
# 9   54    Male                Goa    typical angina       140   239  False
#
#    restecg  thalach  exang  oldpeak  slope  ca  thal    target
# 0     True      187      0      3.5      0   0     2  Effected
# ...

# %%
# sex =index
df = pd.read_csv('E:\ML\hospitalData.csv',index_col = 'sex')
df
# Out:
#         age           Province                cp  trestbps  chol    fbs  \
# sex
# Male     63     Andhra Pradesh      asymptomatic       145   233   True
# Male     37  Arunachal Pradesh  non-anginal pain       130   250  False
# Female   41              Assam   atypical angina       130   204  False
# Male     56              Bihar   atypical angina       120   236  False
# Female   57       Chhattisgarh    typical angina       120   354  False
# ...     ...                ...               ...       ...   ...    ...
# Female   57   Himachal Pradesh    typical angina       140   241  False
# Male     45                Goa      asymptomatic       110   264  False
# Male     68             Sikkim    typical angina       144   193   True
# Male     57            Gujarat    typical angina       130   131  False
# Female   57          Telangana   atypical angina       130   236  False
#
#        restecg  thalach  exang  oldpeak  slope  ca  thal        target
# sex
# ...

# %%
df = pd.read_csv('E:\ML\Statewise.csv')

# %%
df
# Out:
#           Date                        State   TotalSamples       Negative  \
# 0   2020-04-27  Andaman and Nicobar Islands           2848       no value
# 1   2020-04-27               Andhra Pradesh          74551          73374
# 2   2020-04-28            Arunachal Pradesh  not availbale  not availbale
# 3   2020-04-27                        Assam           8117           7985
# 4   2020-04-27                   Chandigarh            843            777
# 5   2020-04-27                        Delhi          39911          34145
# 6   2020-04-27                          Goa           1541  not availbale
# 7   2020-04-27                      Gujarat          53575          50028
# 8   2020-04-27                      Haryana          22993          20702
# 9   2020-04-27             Himachal Pradesh           5106           5022
# 10  2020-04-27            Jammu and Kashmir          14988          14442
# 11  2020-04-27                    Jharkhand       no value            NaN
# ...

# %%
df = pd.read_csv('E:\ML\Statewise.csv', nrows = 10)
df
# Out:
#          Date                        State   TotalSamples       Negative  \
# 0  2020-04-27  Andaman and Nicobar Islands           2848       no value
# 1  2020-04-27               Andhra Pradesh          74551          73374
# 2  2020-04-28            Arunachal Pradesh  not availbale  not availbale
# 3  2020-04-27                        Assam           8117           7985
# 4  2020-04-27                   Chandigarh            843            777
# 5  2020-04-27                        Delhi          39911          34145
# 6  2020-04-27                          Goa           1541  not availbale
# 7  2020-04-27                      Gujarat          53575          50028
# 8  2020-04-27                      Haryana          22993          20702
# 9  2020-04-27             Himachal Pradesh           5106           5022
#
#    Positive
# 0      33.0
# 1    1177.0
# 2       NaN
# 3      35.0
# 4      40.0
# 5    3108.0
# 6       7.0
# 7    3547.0
# 8     301.0
# 9      40.0

# %%
# there is no any header
df = pd.read_csv('E:\ML\Statewise.csv',nrows =10, header = None)
df
# Out:
#             0                            1             2         3         4
# 0        Date                        State  TotalSamples  Negative  Positive
# 1  2020-04-27  Andaman and Nicobar Islands          2848  no value        33
# 2  2020-04-27               Andhra Pradesh         74551     73374       117
# 3  2020-04-27                          NaN           NaN       NaN       NaN
# 4  2020-04-27                        Assam          8117      7985        35
# 5  2020-04-27                   Chandigarh           NaN       777        40
# 6  2020-04-27                        Delhi         39911     34145      3108
# 7  2020-04-27                          Goa          1541       NaN         7
# 8  2020-04-27                      Gujarat         53575     50028      3547
# 9  2020-04-27                      Haryana         22993     20702       301

# %%
df = pd.read_csv('E:\ML\Statewise.csv', header = 0,nrows= 4)
df
# Out:
#          Date                        State   TotalSamples       Negative  \
# 0  2020-04-27  Andaman and Nicobar Islands           2848       no value
# 1  2020-04-27               Andhra Pradesh          74551          73374
# 2  2020-04-28            Arunachal Pradesh  not availbale  not availbale
# 3  2020-04-27                        Assam           8117           7985
#
#    Positive
# 0      33.0
# 1    1177.0
# 2       NaN
# 3      35.0

# %%
df = pd.read_csv('E:\ML\Statewise.csv',usecols=[0,1,2] ,nrows= 4)
df
# Out:
#          Date                        State   TotalSamples
# 0  2020-04-27  Andaman and Nicobar Islands           2848
# 1  2020-04-27               Andhra Pradesh          74551
# 2  2020-04-28            Arunachal Pradesh  not availbale
# 3  2020-04-27                        Assam           8117

# %%
# give name to headers
df1 = pd.read_csv('E:\ML\Statewise.csv',nrows =10, names =['A','B','C','D','E'])
df1
# Out:
#             A                            B             C         D         E
# 0        Date                        State  TotalSamples  Negative  Positive
# 1  2020-04-27  Andaman and Nicobar Islands          2848  no value        33
# 2  2020-04-27               Andhra Pradesh         74551     73374       117
# 3  2020-04-27                          NaN           NaN       NaN       NaN
# 4  2020-04-27                        Assam          8117      7985        35
# 5  2020-04-27                   Chandigarh           NaN       777        40
# 6  2020-04-27                        Delhi         39911     34145      3108
# 7  2020-04-27                          Goa          1541       NaN         7
# 8  2020-04-27                      Gujarat         53575     50028      3547
# 9  2020-04-27                      Haryana         22993     20702       301

# %%
# print first 20 rows
df.head(20)
# Out:
#           Date                        State   TotalSamples       Negative  \
# 0   2020-04-27  Andaman and Nicobar Islands           2848       no value
# 1   2020-04-27               Andhra Pradesh          74551          73374
# 2   2020-04-27                          NaN            NaN            NaN
# 3   2020-04-27                        Assam           8117           7985
# 4   2020-04-27                   Chandigarh            NaN            777
# 5   2020-04-27                        Delhi          39911          34145
# 6   2020-04-27                          Goa           1541            NaN
# 7   2020-04-27                      Gujarat          53575          50028
# 8   2020-04-27                      Haryana          22993          20702
# 9   2020-04-27             Himachal Pradesh           5106           5022
# 10  2020-04-27            Jammu and Kashmir          14988          14442
# 11  2020-04-27                    Jharkhand            NaN            NaN
# ...

# %%
df.head(1)
# Out:
#       0      1             2         3         4
# 0  Date  State  TotalSamples  Negative  Positive

# %%
df.tail(2)
# Out:
#           Date        State TotalSamples Negative  Positive
# 26  2020-04-27  Uttarakhand         5463     4912      51.0
# 27  2020-04-27  West Bengal        12043      NaN     649.0

# %%
df = pd.read_csv('E:\ML\Statewise.csv')
df
# Out:
#           Date                        State   TotalSamples       Negative  \
# 0   2020-04-27  Andaman and Nicobar Islands           2848       no value
# 1   2020-04-27               Andhra Pradesh          74551          73374
# 2   2020-04-27                          NaN            NaN            NaN
# 3   2020-04-27                        Assam           8117           7985
# 4   2020-04-27                   Chandigarh            NaN            777
# 5   2020-04-27                        Delhi          39911          34145
# 6   2020-04-27                          Goa           1541            NaN
# 7   2020-04-27                      Gujarat          53575          50028
# 8   2020-04-27                      Haryana          22993          20702
# 9   2020-04-27             Himachal Pradesh           5106           5022
# 10  2020-04-27            Jammu and Kashmir          14988          14442
# 11  2020-04-27                    Jharkhand            NaN            NaN
# ...

# %%
df = pd.read_csv('E:\ML\Statewise.csv')
df
# Out:
#           Date                        State   TotalSamples       Negative  \
# 0   2020-04-27  Andaman and Nicobar Islands           2848       no value
# 1   2020-04-27               Andhra Pradesh          74551          73374
# 2   2020-04-27                          NaN            NaN            NaN
# 3   2020-04-27                        Assam           8117           7985
# 4   2020-04-27                   Chandigarh            NaN            777
# 5   2020-04-27                        Delhi          39911          34145
# 6   2020-04-27                          Goa           1541            NaN
# 7   2020-04-27                      Gujarat          53575          50028
# 8   2020-04-27                      Haryana          22993          20702
# 9   2020-04-27             Himachal Pradesh           5106           5022
# 10  2020-04-27            Jammu and Kashmir          14988          14442
# 11  2020-04-27                    Jharkhand            NaN            NaN
# ...

# %%
df.dropna()
# Out:
#           Date                        State TotalSamples       Negative  \
# 0   2020-04-27  Andaman and Nicobar Islands         2848       no value
# 1   2020-04-27               Andhra Pradesh        74551          73374
# 3   2020-04-27                        Assam         8117           7985
# 5   2020-04-27                        Delhi        39911          34145
# 7   2020-04-27                      Gujarat        53575          50028
# 8   2020-04-27                      Haryana        22993          20702
# 9   2020-04-27             Himachal Pradesh         5106           5022
# 10  2020-04-27            Jammu and Kashmir        14988          14442
# 12  2020-04-27                    Karnataka        45685          43791
# 13  2020-04-27                       Kerala        23271          22537
# 15  2020-04-27                  Maharashtra       115147         107519
# 16  2020-04-27                    Meghalaya         1254           1182
# ...

# %%
df.dropna(axis = 1)
# Out:
#           Date
# 0   2020-04-27
# 1   2020-04-27
# 2   2020-04-27
# 3   2020-04-27
# 4   2020-04-27
# 5   2020-04-27
# 6   2020-04-27
# 7   2020-04-27
# 8   2020-04-27
# 9   2020-04-27
# 10  2020-04-27
# 11  2020-04-27
# 12  2020-04-27
# 13  2020-04-27
# 14  2020-04-27
# 15  2020-04-27
# 16  2020-04-27
# 17  2020-04-26
# 18  2020-04-27
# 19  2020-04-27
# 20  2020-04-27
# 21  2020-04-27
# 22  2020-04-27
# 23  2020-04-27
# 24  2020-04-22
# 25  2020-04-27
# 26  2020-04-27
# 27  2020-04-27

# %%
df.dropna(how = 'any')
# Out:
#           Date                        State TotalSamples       Negative  \
# 0   2020-04-27  Andaman and Nicobar Islands         2848       no value
# 1   2020-04-27               Andhra Pradesh        74551          73374
# 3   2020-04-27                        Assam         8117           7985
# 5   2020-04-27                        Delhi        39911          34145
# 7   2020-04-27                      Gujarat        53575          50028
# 8   2020-04-27                      Haryana        22993          20702
# 9   2020-04-27             Himachal Pradesh         5106           5022
# 10  2020-04-27            Jammu and Kashmir        14988          14442
# 12  2020-04-27                    Karnataka        45685          43791
# 13  2020-04-27                       Kerala        23271          22537
# 15  2020-04-27                  Maharashtra       115147         107519
# 16  2020-04-27                    Meghalaya         1254           1182
# ...

# %%
df.dropna(axis=1, how='any')
# Out:
#           Date
# 0   2020-04-27
# 1   2020-04-27
# 2   2020-04-27
# 3   2020-04-27
# 4   2020-04-27
# 5   2020-04-27
# 6   2020-04-27
# 7   2020-04-27
# 8   2020-04-27
# 9   2020-04-27
# 10  2020-04-27
# 11  2020-04-27
# 12  2020-04-27
# 13  2020-04-27
# 14  2020-04-27
# 15  2020-04-27
# 16  2020-04-27
# 17  2020-04-26
# 18  2020-04-27
# 19  2020-04-27
# 20  2020-04-27
# 21  2020-04-27
# 22  2020-04-27
# 23  2020-04-27
# 24  2020-04-22
# 25  2020-04-27
# 26  2020-04-27
# 27  2020-04-27

# %%
import pandas as pd

# %%
pd.read_csv('E:\ML\Statewise.csv')
# Out:
#           Date                        State   TotalSamples       Negative  \
# 0   2020-04-27  Andaman and Nicobar Islands           2848       no value
# 1   2020-04-27               Andhra Pradesh          74551          73374
# 2   2020-04-27                          NaN            NaN            NaN
# 3   2020-04-27                        Assam           8117           7985
# 4   2020-04-27                   Chandigarh            NaN            777
# 5   2020-04-27                        Delhi          39911          34145
# 6   2020-04-27                          Goa           1541            NaN
# 7   2020-04-27                      Gujarat          53575          50028
# 8   2020-04-27                      Haryana          22993          20702
# 9   2020-04-27             Himachal Pradesh           5106           5022
# 10  2020-04-27            Jammu and Kashmir          14988          14442
# 11  2020-04-27                    Jharkhand            NaN            NaN
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Khushbu Soni\Panda_Libraries

# %%
pd.read_csv('E:\ML\covidData.csv')
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# ...        ...            ...         ...          ...        ...
# 14497      NaN  International  2020-02-28          705          0
# 14498      NaN  International  2020-02-29          705          0
# 14499      NaN  International  2020-03-01          705          0
# 14500      NaN  International  2020-03-02          705          0
# 14501      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0                 0           0                   18.733
# ...

# %%
pd.read_csv('E:\ML\s.txt')
# Out:
#         state of INDIA
# 0       MandhyaPradesh
# 1                   Ap
# 2            Maharatra
# 3                   Up
# 4            RAjasthan
# 5               Gujrat
# 6                Bihar
# 7                  goa
# 8             Karnatka
# 9            Tamilnadu
# 10              kerala
# 11      Jambhu Kashmir
# 12            Hariyana
# 13              Panjab
# 14         Uttrakhanda
# 15                Asam
# 16            Laddhakh
# 17        Chattishgarh
# 18         West Bangal
# 19             Mizoram
# 20              Sikkim
# 21             Manipur
# 22  Arudanchal pradesh
# 23               Delhi
# 24           Telangana
# 25            Osdisha
# 26          Jharkhanda
# 27           Meghalaya
